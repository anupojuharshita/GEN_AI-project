# %% [markdown]
# <a href="https://colab.research.google.com/github/anupojuharshita/GEN_AI-project/blob/main/display%20lane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/lane_image')
# Out:
# Mounted at /content/lane_image

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path=('/content/lane_image/MyDrive/lane image.jpg')

# %% [markdown]
# display image

# %%
image = cv2.imread(image_path)
if image is not None:
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
  plt.imshow(image)
  plt.axis('on')
  plt.show()
